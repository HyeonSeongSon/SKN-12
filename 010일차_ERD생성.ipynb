# %% [markdown]
# # ERD
# Entity Relationship Diagram(엔티티 관계 다이어그램)의 약자
#
# 데이터베이스 설계 과정에서 사용되는 모델링 기법 중 하나로, 데이터베이스에 저장될 데이터 엔티티(entity)들과 엔티티 간의 관계(relationship)를 시각적으로 표현

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# workbench의 메뉴 - Database - reverse engineer database에서 만들수있음
